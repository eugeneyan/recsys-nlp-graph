# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.append(os.path.dirname(os.getcwd()))

# %%
from collections import Counter
import itertools
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from category_encoders import OrdinalEncoder

from src.utils.logger import logger
from src.utils.io_utils import load_model, save_model
from src.ml.data_loader_with_meta import Sequences, SequencesDataset
from torch.utils.data import DataLoader

# %%
PARAMS = {'dim': 128,
          'window': 5,
          'min_count': 1,
          'negative_samp': 5,
          'epochs': 10,
          'seed': 42}

# %%
dataset = 'electronics'

# %% [markdown]
# ### Try sequence class

# %%
sequences = Sequences('../data/{}_sequences_samp.npy'.format(dataset), 
                      '../data/{}_edges_val_samp.csv'.format(dataset),
                      '../data/{}_meta.csv'.format(dataset))
# Out:
# 2019-12-10 10:01:04,367 - Sequences loaded (length = 5,000)
# 2019-12-10 10:01:04,443 - Validation set loaded: (100000, 3)
# 2019-12-10 10:01:04,453 - Word frequency calculated
# 2019-12-10 10:01:04,488 - Adding val products to word2id, original size: 28695
# 2019-12-10 10:01:04,552 - Added val products to word2id, updated size: 133050
# 2019-12-10 10:01:04,557 - No. of unique tokens: 133050
# 2019-12-10 10:01:05,709 - Model saved to model/word2id
# 2019-12-10 10:01:06,966 - Model saved to model/id2word
# 2019-12-10 10:01:06,967 - Word2Id and Id2Word created and saved
# 2019-12-10 10:01:10,836 - No. of rows in meta before filter by word2id: 498196
# 2019-12-10 10:01:11,174 - No. of rows in meta after filter by word2id: 79566
# 2019-12-10 10:01:13,267 - Model saved to model/encoder
# 2019-12-10 10:01:15,703 - Embedding dimensions: OrderedDict([('product', 133050), ('asin', 79567), ('category_lvl_3', 55), ('brand', 74)])
# 2019-12-10 10:01:16,435 - Model saved to model/meta_dict
# 2019-12-10 10:01:16,462 - Convert sequence and wordfreq to ID
# 2019-12-10 10:01:16,511 - Discard probability calculated
# 2019-12-10 10:01:18,090 - Negative sample table created

# %% [markdown]
# ### Verify meta working correctly

# %%
sequences.meta_dict
# Out:
# {39732: [1, 1, 1],
#  132825: [2, 2, 1],
#  911: [3, 3, 1],
#  3923: [4, 1, 1],
#  852: [5, 1, 1],
#  841: [6, 1, 1],
#  11901: [7, 2, 1],
#  81558: [8, 4, 1],
#  39378: [9, 5, 1],
#  60973: [10, 6, 1],
#  11376: [11, 1, 1],
#  11318: [12, 1, 1],
#  101754: [13, 1, 1],
#  3935: [14, 7, 1],
#  11883: [15, 7, 1],
#  871: [16, 7, 1],
#  3987: [17, 7, 1],
#  11900: [18, 1, 1],
#  3927: [19, 7, 1],
#  1534: [20, 7, 1],
#  11331: [21, 1, 1],
#  42488: [22, 8, 1],
#  41277: [23, 9, 1],
#  46224: [24, 2, 1],
#  125831: [25, 2, 1],
#  3929: [26, 1, 1],
#  51694: [27, 2, 1],
#  29523: [28, 10, 2],
#  97530: [29, 10, 1],
#  117494: [30, 11, 1],
#  11569: [31, 12, 1],
#  125001: [32, 10, 1],
#  22930: [33, 3, 1],
#  48434: [34, 10, 1],
#  6470: [35, 13, 1],
#  31138: [36, 14, 1],
#  128798: [37, 15, 1],
#  97917: [38, 13, 1],
#  90378: [39, 3, 1],
#  102077: [40, 16, 1],
#  51868: [41, 12, 1],
#  126310: [42, 6, 1],
#  24864: [43, 17, 1],
#  46876: [44, 18, 1],
#  121350: [45, 1, 1],
#  90968: [46, 10, 2],
#  101419: [47, 15, 1],
#  32467: [48, 13, 3],
#  108558: [49, 1, 1],
#  78556: [50, 13, 4],
#  100256: [51, 13, 4],
#  42683: [52, 13, 4],
#  17380: [53, 13, 4],
#  108780: [54, 13, 1],
#  30874: [55, 13, 1],
#  44263: [56, 13, 1],
#  71889: [57, 13, 1],
#  61714: [58, 13, 5],
#  77973: [59, 13, 1],
#  80889: [60, 13, 5],
#  60220: [61, 13, 1],
#  44410: [62, 13, 1],
#  115262: [63, 13, 5],
#  123780: [64, 13, 4],
#  119202: [65, 13, 1],
#  126957: [66, 13, 5],
#  29546: [67, 13, 4],
#  54825: [68, 13, 1],
#  132644: [69, 13, 1],
#  49735: [70, 13, 5],
#  130827: [71, 13, 5],
#  61964: [72, 13, 5],
#  107481: [73, 13, 1],
#  28625: [74, 13, 4],
#  97888: [75, 13, 4],
#  58616: [76, 13, 4],
#  112878: [77, 13, 1],
#  79655: [78, 13, 5],
#  25007: [79, 13, 1],
#  97464: [80, 13, 5],
#  115885: [81, 13, 5],
#  103623: [82, 13, 1],
#  38798: [83, 13, 5],
#  128685: [84, 13, 1],
#  42148: [85, 19, 5],
#  89148: [86, 13, 1],
#  86650: [87, 5, 1],
#  83127: [88, 13, 1],
#  29646: [89, 13, 1],
#  97630: [90, 14, 6],
#  109718: [91, 13, 1],
#  13492: [92, 5, 1],
#  45746: [93, 13, 1],
#  37709: [94, 5, 1],
#  124716: [95, 13, 1],
#  97120: [96, 13, 1],
#  50850: [97, 13, 1],
#  86316: [98, 13, 1],
#  84467: [99, 13, 5],
#  76655: [100, 13, 1],
#  65258: [101, 20, 1],
#  29542: [102, 5, 1],
#  38438: [103, 5, 1],
#  44434: [104, 13, 1],
#  109074: [105, 13, 1],
#  66341: [106, 13, 5],
#  29250: [107, 13, 1],
#  105055: [108, 13, 1],
#  14125: [109, 13, 1],
#  70896: [110, 13, 1],
#  104188: [111, 13, 5],
#  48801: [112, 13, 5],
#  51329: [113, 13, 1],
#  30668: [114, 5, 1],
#  10525: [115, 13, 1],
#  129067: [116, 5, 7],
#  13118: [117, 5, 1],
#  84506: [118, 18, 1],
#  68266: [119, 21, 1],
#  89618: [120, 18, 1],
#  40498: [121, 5, 1],
#  81109: [122, 21, 1],
#  65881: [123, 5, 1],
#  23752: [124, 5, 1],
#  99944: [125, 5, 1],
#  31768: [126, 5, 1],
#  26796: [127, 5, 1],
#  41629: [128, 18, 1],
#  26806: [129, 18, 1],
#  26852: [130, 15, 1],
#  33265: [131, 21, 1],
#  85051: [132, 21, 1],
#  26820: [133, 18, 1],
#  26817: [134, 21, 1],
#  26788: [135, 18, 1],
#  98629: [136, 18, 1],
#  35586: [137, 16, 1],
#  109215: [138, 22, 1],
#  1178: [139, 22, 1],
#  74342: [140, 5, 1],
#  2429: [141, 5, 1],
#  100453: [142, 22, 1],
#  123853: [143, 5, 1],
#  26807: [144, 18, 1],
#  111512: [145, 18, 8],
#  17881: [146, 13, 8],
#  123383: [147, 13, 8],
#  85250: [148, 13, 1],
#  35713: [149, 13, 8],
#  14667: [150, 13, 8],
#  11399: [151, 13, 8],
#  125797: [152, 5, 8],
#  15855: [153, 23, 8],
#  130210: [154, 13, 8],
#  2428: [155, 5, 1],
#  21041: [156, 13, 8],
#  122037: [157, 13, 8],
#  11400: [158, 13, 8],
#  46813: [159, 16, 1],
#  48716: [160, 13, 8],
#  110641: [161, 16, 1],
#  108122: [162, 13, 1],
#  107283: [163, 10, 1],
#  112973: [164, 13, 1],
#  40433: [165, 13, 1],
#  127139: [166, 21, 1],
#  77695: [167, 13, 1],
#  25475: [168, 18, 1],
#  11742: [169, 18, 1],
#  26814: [170, 18, 1],
#  125491: [171, 5, 1],
#  114066: [172, 18, 9],
#  31801: [173, 24, 1],
#  43800: [174, 24, 1],
#  3740: [175, 25, 1],
#  43205: [176, 5, 1],
#  87666: [177, 13, 1],
#  70236: [178, 26, 1],
#  21075: [179, 26, 1],
#  112670: [180, 18, 9],
#  102921: [181, 13, 8],
#  10760: [182, 13, 8],
#  107902: [183, 13, 1],
#  116630: [184, 13, 8],
#  105176: [185, 26, 1],
#  69240: [186, 5, 1],
#  41: [187, 27, 10],
#  51787: [188, 27, 10],
#  105: [189, 27, 10],
#  108: [190, 27, 10],
#  44433: [191, 27, 10],
#  119288: [192, 27, 10],
#  115875: [193, 27, 10],
#  21129: [194, 26, 1],
#  14706: [195, 26, 1],
#  80846: [196, 18, 1],
#  733: [197, 19, 1],
#  11743: [198, 18, 9],
#  110552: [199, 1, 1],
#  55147: [200, 5, 1],
#  121543: [201, 5, 1],
#  113285: [202, 5, 1],
#  27764: [203, 5, 1],
#  28368: [204, 28, 11],
#  83970: [205, 24, 1],
#  49509: [206, 13, 1],
#  68776: [207, 5, 9],
#  38013: [208, 1, 12],
#  118195: [209, 21, 9],
#  114012: [210, 29, 1],
#  26821: [211, 1, 9],
#  37239: [212, 13, 8],
#  68913: [213, 28, 1],
#  67880: [214, 23, 1],
#  55149: [215, 29, 1],
#  14778: [216, 15, 1],
#  113160: [217, 10, 13],
#  51982: [218, 1, 1],
#  113863: [219, 24, 14],
#  21733: [220, 24, 14],
#  88692: [221, 5, 1],
#  92731: [222, 1, 1],
#  51226: [223, 1, 1],
#  85305: [224, 13, 1],
#  56993: [225, 22, 1],
#  43357: [226, 5, 1],
#  35606: [227, 27, 1],
#  91024: [228, 27, 1],
#  60173: [229, 24, 1],
#  93568: [230, 10, 1],
#  42489: [231, 13, 1],
#  50240: [232, 5, 1],
#  132920: [233, 5, 1],
#  2020: [234, 13, 1],
#  1284: [235, 5, 1],
#  63293: [236, 13, 15],
#  29462: [237, 21, 1],
#  3702: [238, 30, 1],
#  121700: [239, 1, 1],
#  53848: [240, 28, 1],
#  90983: [241, 28, 1],
#  119939: [242, 28, 1],
#  23132: [243, 25, 1],
#  47575: [244, 13, 8],
#  27308: [245, 28, 1],
#  23136: [246, 25, 1],
#  108338: [247, 25, 1],
#  3675: [248, 25, 1],
#  15530: [249, 28, 1],
#  51048: [250, 28, 1],
#  126612: [251, 28, 1],
#  15532: [252, 28, 1],
#  32310: [253, 5, 1],
#  79304: [254, 28, 1],
#  91036: [255, 28, 1],
#  5369: [256, 5, 1],
#  112095: [257, 21, 1],
#  26801: [258, 1, 16],
#  77095: [259, 29, 16],
#  98012: [260, 13, 16],
#  3687: [261, 25, 1],
#  61784: [262, 28, 1],
#  97519: [263, 18, 1],
#  112064: [264, 18, 1],
#  26143: [265, 18, 1],
#  112016: [266, 28, 1],
#  87216: [267, 31, 1],
#  81430: [268, 31, 1],
#  100460: [269, 31, 7],
#  12044: [270, 32, 1],
#  12130: [271, 31, 7],
#  106932: [272, 28, 1],
#  14708: [273, 26, 1],
#  28889: [274, 27, 10],
#  35: [275, 27, 10],
#  38: [276, 27, 10],
#  117297: [277, 27, 10],
#  47529: [278, 27, 10],
#  15647: [279, 6, 1],
#  114156: [280, 27, 10],
#  83: [281, 27, 10],
#  126665: [282, 27, 10],
#  102: [283, 27, 10],
#  88041: [284, 27, 10],
#  47822: [285, 27, 1],
#  82: [286, 27, 10],
#  99: [287, 27, 10],
#  100: [288, 27, 10],
#  98: [289, 27, 10],
#  14: [290, 27, 10],
#  17833: [291, 32, 1],
#  27306: [292, 28, 17],
#  114546: [293, 28, 1],
#  11691: [294, 28, 17],
#  19268: [295, 28, 17],
#  6523: [296, 28, 17],
#  20574: [297, 33, 1],
#  25764: [298, 13, 18],
#  15484: [299, 5, 18],
#  129521: [300, 22, 1],
#  67066: [301, 13, 1],
#  37695: [302, 27, 1],
#  11152: [303, 18, 1],
#  102737: [304, 18, 1],
#  74322: [305, 18, 1],
#  23064: [306, 14, 6],
#  3700: [307, 14, 6],
#  112437: [308, 26, 1],
#  42703: [309, 26, 1],
#  14735: [310, 26, 1],
#  124628: [311, 26, 1],
#  23297: [312, 26, 1],
#  6734: [313, 23, 1],
#  93929: [314, 18, 1],
#  23588: [315, 34, 7],
#  108798: [316, 18, 7],
#  5998: [317, 32, 7],
#  12118: [318, 18, 7],
#  80771: [319, 34, 7],
#  91518: [320, 18, 1],
#  6610: [321, 8, 7],
#  15127: [322, 18, 7],
#  122532: [323, 34, 7],
#  22532: [324, 6, 16],
#  107568: [325, 25, 1],
#  92574: [326, 23, 1],
#  85353: [327, 23, 1],
#  60924: [328, 23, 1],
#  104402: [329, 23, 1],
#  127199: [330, 34, 1],
#  104102: [331, 34, 1],
#  125782: [332, 34, 1],
#  23715: [333, 34, 1],
#  118809: [334, 34, 1],
#  65367: [335, 31, 7],
#  245: [336, 5, 15],
#  78729: [337, 21, 1],
#  12802: [338, 5, 15],
#  16528: [339, 5, 1],
#  90344: [340, 21, 1],
#  83023: [341, 5, 1],
#  13936: [342, 5, 1],
#  109353: [343, 1, 1],
#  94980: [344, 21, 1],
#  128002: [345, 21, 1],
#  131465: [346, 27, 10],
#  53303: [347, 5, 1],
#  61953: [348, 28, 1],
#  84544: [349, 28, 1],
#  120802: [350, 5, 1],
#  47584: [351, 13, 1],
#  27393: [352, 13, 1],
#  52667: [353, 5, 8],
#  110470: [354, 13, 8],
#  46569: [355, 13, 8],
#  31317: [356, 21, 1],
#  48870: [357, 21, 1],
#  71582: [358, 13, 8],
#  55309: [359, 13, 8],
#  21042: [360, 13, 8],
#  100607: [361, 13, 8],
#  39555: [362, 5, 8],
#  63326: [363, 5, 8],
#  26704: [364, 5, 8],
#  70477: [365, 13, 8],
#  1769: [366, 13, 8],
#  72352: [367, 13, 1],
#  23857: [368, 13, 8],
#  50821: [369, 13, 8],
#  15681: [370, 13, 1],
#  108545: [371, 13, 8],
#  13914: [372, 13, 8],
#  93760: [373, 13, 8],
#  33187: [374, 13, 8],
#  60835: [375, 13, 8],
#  68881: [376, 13, 8],
#  36428: [377, 13, 8],
#  36029: [378, 13, 8],
#  84476: [379, 13, 8],
#  15834: [380, 13, 8],
#  80550: [381, 13, 8],
#  54324: [382, 13, 8],
#  43703: [383, 13, 8],
#  60672: [384, 28, 1],
#  123593: [385, 28, 1],
#  75305: [386, 27, 1],
#  110: [387, 27, 10],
#  59652: [388, 13, 8],
#  68: [389, 13, 8],
#  88266: [390, 13, 8],
#  41025: [391, 13, 1],
#  31774: [392, 5, 8],
#  11248: [393, 13, 8],
#  92605: [394, 27, 10],
#  96142: [395, 27, 10],
#  47773: [396, 13, 8],
#  10575: [397, 13, 8],
#  42615: [398, 13, 1],
#  4070: [399, 27, 10],
#  77839: [400, 13, 1],
#  130803: [401, 13, 8],
#  79: [402, 27, 10],
#  96458: [403, 21, 1],
#  106298: [404, 13, 8],
#  60663: [405, 13, 8],
#  17500: [406, 19, 1],
#  91224: [407, 13, 8],
#  91350: [408, 21, 19],
#  123525: [409, 13, 20],
#  52064: [410, 13, 8],
#  67957: [411, 13, 8],
#  37713: [412, 1, 12],
#  60473: [413, 13, 12],
#  49683: [414, 13, 12],
#  79166: [415, 13, 12],
#  28158: [416, 13, 1],
#  100792: [417, 24, 1],
#  57767: [418, 13, 12],
#  107698: [419, 13, 8],
#  9437: [420, 19, 1],
#  54626: [421, 13, 1],
#  10632: [422, 19, 1],
#  87973: [423, 13, 1],
#  86534: [424, 11, 1],
#  14321: [425, 18, 1],
#  2893: [426, 18, 1],
#  62680: [427, 18, 1],
#  12009: [428, 18, 1],
#  12319: [429, 18, 1],
#  400: [430, 18, 1],
#  23553: [431, 18, 1],
#  35945: [432, 18, 1],
#  56578: [433, 18, 1],
#  109871: [434, 18, 1],
#  72892: [435, 18, 1],
#  104826: [436, 18, 1],
#  23552: [437, 18, 1],
#  6626: [438, 18, 1],
#  34361: [439, 18, 1],
#  5687: [440, 18, 1],
#  127513: [441, 18, 1],
#  5795: [442, 18, 1],
#  17720: [443, 18, 1],
#  108244: [444, 18, 1],
#  5985: [445, 18, 1],
#  118404: [446, 18, 1],
#  49310: [447, 18, 1],
#  26094: [448, 18, 1],
#  6544: [449, 18, 1],
#  94417: [450, 11, 1],
#  9521: [451, 18, 1],
#  109369: [452, 18, 1],
#  17643: [453, 18, 1],
#  87762: [454, 18, 1],
#  6557: [455, 18, 1],
#  19911: [456, 18, 1],
#  128963: [457, 34, 1],
#  2884: [458, 18, 1],
#  336: [459, 18, 1],
#  17741: [460, 18, 1],
#  27321: [461, 28, 1],
#  12017: [462, 18, 1],
#  99888: [463, 11, 1],
#  66461: [464, 18, 1],
#  95010: [465, 18, 1],
#  14320: [466, 18, 1],
#  44962: [467, 18, 1],
#  19257: [468, 31, 1],
#  63302: [469, 11, 1],
#  40210: [470, 18, 1],
#  77840: [471, 18, 1],
#  26037: [472, 18, 1],
#  12747: [473, 18, 1],
#  19886: [474, 18, 1],
#  19899: [475, 18, 1],
#  6625: [476, 18, 1],
#  25904: [477, 18, 1],
#  19884: [478, 18, 1],
#  19867: [479, 18, 1],
#  68965: [480, 35, 1],
#  31070: [481, 5, 1],
#  100017: [482, 35, 1],
#  12000: [483, 18, 7],
#  27307: [484, 28, 1],
#  27305: [485, 28, 1],
#  41813: [486, 6, 21],
#  89467: [487, 5, 21],
#  22243: [488, 18, 22],
#  95093: [489, 13, 23],
#  28146: [490, 6, 21],
#  18824: [491, 13, 21],
#  92813: [492, 13, 21],
#  108254: [493, 24, 24],
#  127136: [494, 13, 21],
#  2767: [495, 13, 25],
#  17880: [496, 13, 25],
#  37954: [497, 13, 1],
#  6189: [498, 13, 25],
#  2994: [499, 5, 1],
#  26682: [500, 13, 25],
#  98783: [501, 13, 25],
#  27361: [502, 28, 1],
#  6641: [503, 5, 25],
#  44404: [504, 21, 1],
#  82172: [505, 13, 23],
#  85049: [506, 13, 25],
#  119491: [507, 13, 25],
#  42404: [508, 5, 25],
#  119406: [509, 13, 1],
#  129413: [510, 13, 1],
#  44352: [511, 13, 21],
#  54091: [512, 13, 25],
#  63275: [513, 13, 25],
#  97366: [514, 13, 21],
#  30030: [515, 13, 25],
#  30112: [516, 13, 25],
#  114371: [517, 17, 23],
#  41386: [518, 18, 22],
#  5114: [519, 13, 23],
#  23770: [520, 5, 1],
#  76389: [521, 13, 23],
#  94025: [522, 24, 25],
#  27155: [523, 13, 23],
#  68209: [524, 13, 23],
#  2594: [525, 5, 25],
#  130380: [526, 6, 21],
#  69026: [527, 13, 23],
#  118220: [528, 13, 25],
#  130446: [529, 13, 1],
#  89353: [530, 13, 23],
#  51601: [531, 13, 25],
#  113012: [532, 21, 1],
#  104428: [533, 17, 23],
#  52686: [534, 6, 1],
#  74716: [535, 13, 23],
#  108654: [536, 6, 23],
#  56008: [537, 6, 21],
#  9417: [538, 13, 23],
#  18794: [539, 13, 23],
#  107214: [540, 13, 23],
#  120863: [541, 36, 1],
#  62754: [542, 6, 21],
#  75545: [543, 24, 24],
#  85933: [544, 13, 23],
#  116332: [545, 13, 23],
#  19039: [546, 5, 1],
#  39724: [547, 24, 1],
#  3677: [548, 25, 1],
#  31237: [549, 28, 1],
#  100680: [550, 28, 1],
#  3739: [551, 25, 1],
#  97617: [552, 28, 1],
#  28428: [553, 28, 1],
#  119742: [554, 28, 1],
#  27362: [555, 28, 1],
#  33125: [556, 1, 1],
#  105962: [557, 1, 1],
#  110376: [558, 31, 1],
#  37887: [559, 31, 7],
#  17826: [560, 31, 7],
#  113782: [561, 31, 7],
#  73955: [562, 5, 1],
#  95114: [563, 18, 1],
#  75232: [564, 18, 1],
#  96942: [565, 5, 18],
#  55674: [566, 6, 1],
#  3703: [567, 30, 6],
#  131134: [568, 21, 1],
#  5061: [569, 23, 1],
#  67388: [570, 18, 1],
#  17801: [571, 31, 1],
#  88251: [572, 28, 1],
#  29311: [573, 28, 1],
#  31130: [574, 28, 1],
#  84297: [575, 26, 1],
#  36929: [576, 5, 18],
#  15449: [577, 5, 18],
#  15513: [578, 5, 18],
#  106454: [579, 5, 18],
#  15415: [580, 5, 18],
#  132809: [581, 5, 18],
#  101781: [582, 5, 18],
#  45: [583, 27, 10],
#  83164: [584, 16, 1],
#  108769: [585, 25, 1],
#  3738: [586, 25, 1],
#  3723: [587, 25, 1],
#  117345: [588, 25, 1],
#  48820: [589, 16, 1],
#  48626: [590, 37, 1],
#  60488: [591, 13, 4],
#  93284: [592, 18, 7],
#  23811: [593, 21, 1],
#  64771: [594, 28, 1],
#  10: [595, 27, 10],
#  101819: [596, 27, 10],
#  4069: [597, 27, 10],
#  83987: [598, 28, 1],
#  39: [599, 27, 10],
#  2261: [600, 31, 7],
#  55103: [601, 5, 1],
#  38791: [602, 31, 11],
#  19937: [603, 18, 11],
#  80376: [604, 31, 11],
#  388: [605, 31, 1],
#  12314: [606, 31, 11],
#  101064: [607, 31, 11],
#  19936: [608, 18, 11],
#  96812: [609, 18, 11],
#  10645: [610, 31, 11],
#  69056: [611, 31, 11],
#  36183: [612, 31, 11],
#  2184: [613, 31, 1],
#  17728: [614, 31, 1],
#  20891: [615, 31, 11],
#  91009: [616, 31, 11],
#  95766: [617, 31, 1],
#  53223: [618, 31, 11],
#  8390: [619, 31, 11],
#  395: [620, 31, 1],
#  20441: [621, 31, 11],
#  69885: [622, 31, 1],
#  109301: [623, 1, 1],
#  107180: [624, 10, 26],
#  92162: [625, 1, 22],
#  27352: [626, 28, 1],
#  28566: [627, 26, 9],
#  14715: [628, 26, 1],
#  14781: [629, 26, 1],
#  98706: [630, 26, 1],
#  20042: [631, 26, 1],
#  2493: [632, 4, 1],
#  2726: [633, 5, 1],
#  13454: [634, 18, 16],
#  107661: [635, 21, 1],
#  14869: [636, 13, 1],
#  80607: [637, 22, 1],
#  49421: [638, 13, 8],
#  12352: [639, 35, 1],
#  27344: [640, 28, 1],
#  8527: [641, 31, 7],
#  403: [642, 18, 1],
#  118529: [643, 18, 1],
#  39381: [644, 32, 1],
#  86336: [645, 28, 1],
#  19938: [646, 18, 1],
#  404: [647, 18, 1],
#  8619: [648, 18, 1],
#  19889: [649, 18, 11],
#  659: [650, 24, 1],
#  126756: [651, 5, 1],
#  96803: [652, 26, 1],
#  85373: [653, 5, 9],
#  19269: [654, 28, 17],
#  117330: [655, 27, 1],
#  124437: [656, 5, 1],
#  36879: [657, 31, 1],
#  19887: [658, 31, 1],
#  79427: [659, 31, 1],
#  103239: [660, 21, 1],
#  84233: [661, 38, 1],
#  26775: [662, 15, 9],
#  89161: [663, 15, 1],
#  37809: [664, 18, 1],
#  5451: [665, 38, 1],
#  21999: [666, 39, 27],
#  126772: [667, 5, 1],
#  115668: [668, 5, 15],
#  2665: [669, 39, 27],
#  114584: [670, 5, 1],
#  77265: [671, 5, 1],
#  123962: [672, 5, 1],
#  93573: [673, 18, 1],
#  100691: [674, 5, 1],
#  85157: [675, 5, 1],
#  92716: [676, 18, 17],
#  6710: [677, 5, 1],
#  99898: [678, 5, 1],
#  41918: [679, 1, 1],
#  66175: [680, 18, 1],
#  14040: [681, 8, 1],
#  94996: [682, 18, 1],
#  14870: [683, 18, 9],
#  27209: [684, 8, 1],
#  104047: [685, 5, 1],
#  51447: [686, 1, 1],
#  30554: [687, 39, 1],
#  17489: [688, 13, 23],
#  104333: [689, 5, 1],
#  131652: [690, 5, 1],
#  63001: [691, 28, 17],
#  52685: [692, 1, 1],
#  33489: [693, 5, 1],
#  92504: [694, 13, 1],
#  130735: [695, 13, 8],
#  109249: [696, 13, 8],
#  101288: [697, 23, 8],
#  80298: [698, 39, 1],
#  47779: [699, 5, 1],
#  116080: [700, 5, 1],
#  65485: [701, 13, 1],
#  26794: [702, 18, 9],
#  91256: [703, 5, 15],
#  44459: [704, 21, 1],
#  32332: [705, 5, 1],
#  8688: [706, 18, 1],
#  50096: [707, 13, 23],
#  13253: [708, 8, 23],
#  11837: [709, 13, 23],
#  87833: [710, 13, 23],
#  21725: [711, 13, 23],
#  6472: [712, 24, 23],
#  69154: [713, 31, 1],
#  389: [714, 31, 11],
#  130572: [715, 4, 1],
#  122814: [716, 4, 1],
#  15618: [717, 28, 17],
#  27329: [718, 28, 1],
#  120184: [719, 4, 1],
#  88108: [720, 13, 1],
#  8494: [721, 18, 9],
#  26789: [722, 18, 9],
#  35594: [723, 39, 1],
#  70606: [724, 11, 1],
#  83613: [725, 18, 1],
#  37475: [726, 18, 9],
#  129189: [727, 18, 9],
#  81565: [728, 18, 1],
#  126359: [729, 5, 15],
#  71125: [730, 13, 15],
#  41731: [731, 13, 15],
#  56499: [732, 5, 1],
#  234: [733, 5, 15],
#  74141: [734, 20, 18],
#  67687: [735, 25, 1],
#  106684: [736, 4, 1],
#  32193: [737, 24, 1],
#  95164: [738, 24, 14],
#  104698: [739, 18, 9],
#  63981: [740, 5, 1],
#  5927: [741, 20, 1],
#  80975: [742, 25, 7],
#  76372: [743, 30, 1],
#  90391: [744, 13, 1],
#  21638: [745, 1, 1],
#  72104: [746, 5, 1],
#  86677: [747, 15, 1],
#  39496: [748, 15, 1],
#  68686: [749, 26, 6],
#  99697: [750, 25, 28],
#  6147: [751, 18, 28],
#  6166: [752, 18, 28],
#  109995: [753, 18, 28],
#  6127: [754, 18, 28],
#  61663: [755, 18, 28],
#  30774: [756, 1, 22],
#  12205: [757, 13, 8],
#  117736: [758, 18, 1],
#  68082: [759, 39, 1],
#  24118: [760, 5, 1],
#  10842: [761, 4, 29],
#  39762: [762, 13, 1],
#  7144: [763, 13, 1],
#  27571: [764, 13, 1],
#  126160: [765, 13, 1],
#  31406: [766, 13, 1],
#  121452: [767, 13, 1],
#  51647: [768, 13, 1],
#  36965: [769, 34, 1],
#  70057: [770, 13, 1],
#  45490: [771, 34, 1],
#  29658: [772, 13, 8],
#  111028: [773, 22, 8],
#  34536: [774, 5, 8],
#  2728: [775, 5, 8],
#  105481: [776, 13, 8],
#  30583: [777, 28, 1],
#  100413: [778, 13, 8],
#  40444: [779, 13, 8],
#  80086: [780, 13, 8],
#  72355: [781, 13, 8],
#  10574: [782, 13, 8],
#  75150: [783, 13, 8],
#  49224: [784, 13, 8],
#  114697: [785, 13, 8],
#  115383: [786, 13, 8],
#  4665: [787, 13, 8],
#  105918: [788, 13, 8],
#  105115: [789, 13, 8],
#  28870: [790, 5, 8],
#  130698: [791, 6, 8],
#  104508: [792, 13, 8],
#  42449: [793, 13, 8],
#  93417: [794, 13, 25],
#  11440: [795, 13, 8],
#  124528: [796, 5, 25],
#  99631: [797, 13, 8],
#  73259: [798, 13, 8],
#  19364: [799, 6, 25],
#  2773: [800, 27, 10],
#  81: [801, 27, 10],
#  56580: [802, 17, 25],
#  110354: [803, 13, 10],
#  111297: [804, 5, 25],
#  110862: [805, 13, 25],
#  62015: [806, 13, 25],
#  57735: [807, 13, 25],
#  8133: [808, 13, 25],
#  8227: [809, 13, 25],
#  80141: [810, 13, 25],
#  91: [811, 27, 10],
#  70226: [812, 13, 25],
#  40495: [813, 5, 23],
#  126673: [814, 21, 1],
#  2425: [815, 5, 1],
#  41936: [816, 13, 25],
#  7034: [817, 13, 25],
#  12606: [818, 21, 9],
#  112267: [819, 27, 10],
#  13179: [820, 13, 25],
#  51218: [821, 13, 23],
#  73244: [822, 13, 8],
#  46068: [823, 5, 23],
#  2022: [824, 13, 23],
#  124450: [825, 5, 23],
#  10049: [826, 13, 23],
#  95853: [827, 13, 25],
#  104619: [828, 13, 23],
#  48226: [829, 13, 23],
#  71938: [830, 13, 8],
#  104900: [831, 13, 23],
#  131038: [832, 5, 1],
#  94036: [833, 13, 21],
#  56223: [834, 13, 23],
#  112139: [835, 13, 25],
#  19041: [836, 5, 8],
#  57154: [837, 13, 21],
#  20416: [838, 13, 21],
#  13948: [839, 5, 21],
#  104939: [840, 13, 25],
#  49877: [841, 13, 25],
#  115546: [842, 13, 21],
#  111069: [843, 13, 21],
#  104416: [844, 13, 21],
#  98922: [845, 5, 23],
#  3207: [846, 13, 21],
#  13902: [847, 5, 1],
#  103249: [848, 13, 21],
#  111527: [849, 13, 21],
#  130906: [850, 17, 21],
#  6669: [851, 13, 25],
#  36313: [852, 27, 1],
#  62926: [853, 5, 23],
#  51154: [854, 13, 23],
#  86680: [855, 13, 21],
#  78875: [856, 13, 25],
#  64683: [857, 13, 25],
#  75040: [858, 13, 1],
#  8134: [859, 13, 25],
#  87707: [860, 13, 21],
#  105803: [861, 5, 1],
#  51290: [862, 24, 1],
#  11198: [863, 5, 21],
#  59875: [864, 13, 21],
#  88095: [865, 27, 1],
#  2707: [866, 13, 21],
#  114058: [867, 5, 21],
#  106020: [868, 5, 1],
#  18823: [869, 5, 21],
#  6339: [870, 5, 23],
#  8769: [871, 5, 1],
#  7036: [872, 5, 21],
#  123059: [873, 13, 21],
#  8131: [874, 13, 25],
#  52929: [875, 5, 1],
#  23803: [876, 5, 1],
#  91904: [877, 5, 1],
#  130943: [878, 5, 1],
#  127562: [879, 24, 1],
#  23814: [880, 5, 1],
#  18431: [881, 13, 1],
#  101392: [882, 13, 1],
#  74013: [883, 6, 1],
#  93567: [884, 13, 25],
#  58272: [885, 13, 25],
#  5082: [886, 13, 25],
#  34263: [887, 13, 3],
#  38046: [888, 5, 30],
#  81669: [889, 5, 30],
#  86504: [890, 5, 30],
#  18741: [891, 5, 30],
#  28928: [892, 5, 30],
#  27219: [893, 5, 30],
#  38902: [894, 5, 30],
#  30732: [895, 5, 30],
#  26598: [896, 5, 30],
#  7081: [897, 5, 30],
#  14405: [898, 5, 30],
#  12761: [899, 5, 30],
#  12758: [900, 5, 30],
#  106089: [901, 5, 30],
#  47961: [902, 5, 30],
#  12872: [903, 5, 30],
#  126017: [904, 5, 30],
#  22732: [905, 5, 30],
#  124077: [906, 5, 30],
#  119002: [907, 5, 30],
#  24003: [908, 5, 30],
#  106242: [909, 5, 30],
#  63643: [910, 5, 30],
#  21660: [911, 5, 30],
#  71665: [912, 5, 30],
#  109154: [913, 5, 30],
#  132881: [914, 5, 30],
#  8581: [915, 5, 30],
#  10635: [916, 5, 30],
#  120916: [917, 5, 30],
#  64861: [918, 5, 30],
#  43600: [919, 5, 30],
#  23827: [920, 5, 30],
#  30316: [921, 5, 30],
#  3837: [922, 8, 30],
#  65459: [923, 5, 30],
#  15211: [924, 5, 30],
#  23919: [925, 5, 30],
#  12781: [926, 8, 30],
#  8156: [927, 5, 30],
#  64163: [928, 5, 30],
#  38923: [929, 8, 30],
#  96841: [930, 5, 30],
#  55201: [931, 5, 30],
#  2732: [932, 5, 30],
#  12868: [933, 5, 30],
#  12789: [934, 5, 30],
#  34557: [935, 5, 30],
#  117624: [936, 5, 30],
#  81707: [937, 5, 30],
#  9004: [938, 5, 30],
#  111801: [939, 5, 30],
#  15267: [940, 5, 30],
#  3835: [941, 5, 30],
#  55434: [942, 5, 30],
#  80423: [943, 5, 30],
#  57415: [944, 5, 30],
#  117143: [945, 5, 30],
#  51104: [946, 5, 30],
#  17541: [947, 5, 30],
#  120629: [948, 8, 30],
#  74771: [949, 5, 30],
#  18738: [950, 5, 30],
#  36708: [951, 8, 30],
#  74418: [952, 5, 30],
#  15212: [953, 5, 30],
#  109786: [954, 5, 30],
#  4666: [955, 5, 30],
#  78739: [956, 5, 30],
#  22813: [957, 5, 30],
#  121083: [958, 5, 30],
#  125056: [959, 8, 30],
#  83207: [960, 5, 30],
#  127593: [961, 31, 1],
#  12784: [962, 5, 30],
#  10954: [963, 13, 30],
#  96946: [964, 5, 30],
#  113370: [965, 5, 30],
#  43251: [966, 8, 30],
#  103901: [967, 5, 30],
#  43931: [968, 13, 1],
#  65649: [969, 13, 15],
#  69303: [970, 5, 30],
#  12837: [971, 5, 30],
#  9511: [972, 13, 25],
#  41101: [973, 5, 1],
#  36128: [974, 26, 1],
#  70525: [975, 39, 1],
#  16894: [976, 5, 1],
#  52490: [977, 18, 1],
#  95439: [978, 18, 1],
#  119482: [979, 25, 1],
#  3755: [980, 25, 11],
#  31689: [981, 13, 25],
#  114961: [982, 13, 25],
#  68741: [983, 13, 1],
#  10107: [984, 24, 1],
#  110319: [985, 13, 1],
#  132606: [986, 5, 12],
#  92324: [987, 5, 12],
#  72746: [988, 22, 12],
#  35649: [989, 1, 12],
#  116340: [990, 13, 12],
#  56949: [991, 5, 12],
#  125478: [992, 8, 12],
#  50686: [993, 13, 12],
#  130549: [994, 22, 12],
#  660: [995, 24, 1],
#  24493: [996, 5, 12],
#  89177: [997, 22, 12],
#  108302: [998, 13, 23],
#  123710: [999, 13, 23],
#  54922: [1000, 13, 23],
#  ...}

# %%
asin = sequences.id2word[97530]
print(asin)
# Out:
# 5342765439

# %%
sequences.meta[sequences.meta['asin'] == asin]
# Out:
#            asin                                        description  \
# 144  5342765439  hand-crafted crystal flash drive(8g),works ver...
#
#                                             categories  \
# 144  ['electronics', 'computers & accessories', 'da...
#
#                                                  title  price  related brand  \
# 144  mickey logo crystal usb flash drive with neckl...     18        1  MISC
#
#     category_lvl_1           category_lvl_2 category_lvl_3    category_lvl_4  \
# 144    electronics  computers & accessories   data storage  usb flash drives
#
#       productid
# 144  5342765439

# %%
sequences.meta[sequences.meta['asin'] == asin].asin
# Out:
# 144    5342765439
# Name: asin, dtype: object

# %%
sequences.encoder.category_mapping[0]['mapping'][sequences.meta[sequences.meta['asin'] == asin].asin]
# Out:
# asin
# 5342765439    29
# dtype: int64

# %%
# 1 = Misc, 2 = covers, 7 = tablets, 10 = data storage
sequences.encoder.category_mapping[1]['mapping'][sequences.meta[sequences.meta['asin'] == asin].category_lvl_3]
# Out:
# category_lvl_3
# data storage    10
# dtype: int64

# %%
# 1 = Misc
sequences.encoder.category_mapping[1]['mapping'][sequences.meta[sequences.meta['asin'] == asin].brand]
# Out:
# brand
# MISC    1
# dtype: int64

# %%
# 1 = Misc
sequences.encoder.category_mapping[1]['mapping']
# Out:
# MISC                                      1
# covers                                    2
# touch screen tablet accessories           3
# car electronics                           4
# audio & video accessories                 5
# computer components                       6
# tablets                                   7
# NA_VALUE                                  8
# blu-ray players & recorders               9
# data storage                             10
# lighting & studio                        11
# video surveillance                       12
# cables & accessories                     13
# gps system accessories                   14
# mp3 players & accessories                15
# pdas, handhelds & accessories            16
# external components                      17
# accessories                              18
# laptop & netbook computer accessories    19
# vehicle electronics accessories          20
# blank media                              21
# telephone accessories                    22
# cord management                          23
# networking products                      24
# binoculars & scopes                      25
# cb & two-way radios                      26
# office electronics accessories           27
# film photography                         28
# radios                                   29
# sports & handheld gps                    30
# lenses                                   31
# flashes                                  32
# tripods & monopods                       33
# bags & cases                             34
# video                                    35
# routers                                  36
# batteries, chargers & accessories        37
# mounts                                   38
# stereo components                        39
# digital cameras                          40
# marine electronics                       41
# digital voice recorders                  42
# underwater photography                   43
# laptops                                  44
# home security systems                    45
# basic cases                              46
# monitors                                 47
# dvd players & recorders                  48
# webcams                                  49
# streaming media players                  50
# surveillance video equipment             51
# video projectors                         52
# desktops                                 53
# televisions                              54
# NaN                                      -2
# dtype: int64

# %%
pairs = sequences.get_pairs(0)
pairs

# %%
neg_samples = []
for center, context in pairs:
    neg_samples.append(sequences.get_negative_samples(context))
neg_samples[:5]

# %%
seq_dset = SequencesDataset(sequences)

# %%
for i, batch in enumerate(seq_dset):
    logger.info(batch)
    if i > 3:
        break

# %%
center = [pair[0] for pair in batch[0]]
context = [pair[1] for pair in batch[0]]
neg_context = batch[1]

# %%
seq_dloader = DataLoader(dataset=seq_dset, batch_size=2, shuffle=False, collate_fn=seq_dset.collate)

# %%
for i, batches in enumerate(seq_dloader):
    centers, contexts, neg_contexts = batches
    if i == 0:
        break

# %%
batches[0]

# %%
batches[1]

# %%
batches[2]

# %% [markdown]
# ### Init skipgram

# %%
sequences.emb_sizes

# %%
emb_dim = 128

# %%
center_embeddings = nn.ModuleList()
for k, v in sequences.emb_sizes.items():
    center_embeddings.append(nn.Embedding(v, emb_dim, sparse=True))
    
context_embeddings = nn.ModuleList()
for k, v in sequences.emb_sizes.items():
    context_embeddings.append(nn.Embedding(v, emb_dim, sparse=True))

# %%
emb_range = 0.5 / emb_dim

# %%
for emb in center_embeddings:
    emb.weight.data.uniform_(-emb_range, emb_range)
    
for emb in context_embeddings:
    emb.weight.data.uniform_(0, 0)

# %%
x.num_embeddings

# %%
context_embeddings[0]

# %%
center_embeddings

# %%
centers = torch.LongTensor(batch[0][5][0])
centers

# %%
centers

# %%
emb_center = []

# %%
for i, center in enumerate(centers):
    logger.info('i: {}, center: {}'.format(i, center))
    emb_center.append(center_embeddings[i](center))

# %%
torch.mean(torch.stack(emb_center), axis=0)

# %%
torch.stack(emb_center)
