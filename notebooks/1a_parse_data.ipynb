# %%
import sys
import os

sys.path.append(os.path.dirname(os.getcwd()))

# %%
import numpy as np
import pandas as pd
import gzip
from src.utils.logger import logger

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

# %%
def get_df(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
        if i % 10000 == 0:
            logger.info('Rows processed: {:,}'.format(i))
    return pd.DataFrame.from_dict(df, orient='index')

# %%
df = get_df('../data/meta_Electronics.json.gz')
# Out:
# 2019-12-05 12:46:19,889 - Rows processed: 10,000
# 2019-12-05 12:46:20,813 - Rows processed: 20,000
# 2019-12-05 12:46:25,294 - Rows processed: 30,000
# 2019-12-05 12:46:26,184 - Rows processed: 40,000
# 2019-12-05 12:46:27,042 - Rows processed: 50,000
# 2019-12-05 12:46:27,872 - Rows processed: 60,000
# 2019-12-05 12:46:28,698 - Rows processed: 70,000
# 2019-12-05 12:46:29,525 - Rows processed: 80,000
# 2019-12-05 12:46:30,356 - Rows processed: 90,000
# 2019-12-05 12:46:31,232 - Rows processed: 100,000
# 2019-12-05 12:46:32,036 - Rows processed: 110,000
# 2019-12-05 12:46:32,868 - Rows processed: 120,000
# 2019-12-05 12:46:33,685 - Rows processed: 130,000
# 2019-12-05 12:46:34,569 - Rows processed: 140,000
# 2019-12-05 12:46:35,471 - Rows processed: 150,000
# 2019-12-05 12:46:36,353 - Rows processed: 160,000
# 2019-12-05 12:46:37,170 - Rows processed: 170,000
# 2019-12-05 12:46:38,070 - Rows processed: 180,000
# 2019-12-05 12:46:38,889 - Rows processed: 190,000
# 2019-12-05 12:46:39,705 - Rows processed: 200,000
# 2019-12-05 12:46:40,601 - Rows processed: 210,000
# 2019-12-05 12:46:41,454 - Rows processed: 220,000
# 2019-12-05 12:46:42,260 - Rows processed: 230,000
# 2019-12-05 12:46:43,111 - Rows processed: 240,000
# 2019-12-05 12:46:43,947 - Rows processed: 250,000
# 2019-12-05 12:46:44,772 - Rows processed: 260,000
# 2019-12-05 12:46:45,606 - Rows processed: 270,000
# 2019-12-05 12:46:46,456 - Rows processed: 280,000
# 2019-12-05 12:46:47,320 - Rows processed: 290,000
# 2019-12-05 12:46:48,233 - Rows processed: 300,000
# 2019-12-05 12:46:49,125 - Rows processed: 310,000
# 2019-12-05 12:46:50,022 - Rows processed: 320,000
# 2019-12-05 12:46:50,943 - Rows processed: 330,000
# 2019-12-05 12:46:51,864 - Rows processed: 340,000
# 2019-12-05 12:46:52,759 - Rows processed: 350,000
# 2019-12-05 12:46:57,195 - Rows processed: 360,000
# 2019-12-05 12:46:58,171 - Rows processed: 370,000
# 2019-12-05 12:46:59,112 - Rows processed: 380,000
# 2019-12-05 12:47:00,047 - Rows processed: 390,000
# 2019-12-05 12:47:00,936 - Rows processed: 400,000
# 2019-12-05 12:47:01,945 - Rows processed: 410,000
# 2019-12-05 12:47:02,969 - Rows processed: 420,000
# 2019-12-05 12:47:03,976 - Rows processed: 430,000
# 2019-12-05 12:47:05,040 - Rows processed: 440,000
# 2019-12-05 12:47:06,151 - Rows processed: 450,000
# 2019-12-05 12:47:07,290 - Rows processed: 460,000
# 2019-12-05 12:47:08,388 - Rows processed: 470,000
# 2019-12-05 12:47:09,490 - Rows processed: 480,000
# 2019-12-05 12:47:10,686 - Rows processed: 490,000

# %%
from pandas.api.types import is_object_dtype

# Lowercase Functions
def lowercase_df(df: pd.DataFrame) -> pd.DataFrame:
    """
    Lowercase characters from all columns in a dataframe.

    Args:
        df: Pandas dataframe

    Returns:
        Lowercased dataframe
    """
    df = df.copy()
    for col in df.columns:
        if is_object_dtype(df[col]):
            df = lowercase_cols(df, [col])
    return df


def lowercase_cols(df: pd.DataFrame, colnames) -> pd.DataFrame:
    """
    Lowercase characters from specified columns in a dataframe

    Args:
        df: Pandas dataframe
        colnames: Names of columns to be lowercased

    Returns: Lowercased dataframe

    """
    df = df.copy()
    for col in colnames:
        assert df[col].dtype != np.float64 and df[col].dtype != np.int64, \
            'Trying to lowercase a non-string column: {}'.format(col)
        df[col] = df[col].str.lower()
    return df

# %%
df.head()
# Out:
#          asin                                              imUrl  \
# 0  0132793040  http://ecx.images-amazon.com/images/I/31JIPhp%...
# 1  0321732944  http://ecx.images-amazon.com/images/I/31uogm6Y...
# 2  0439886341  http://ecx.images-amazon.com/images/I/51k0qa8f...
# 3  0511189877  http://ecx.images-amazon.com/images/I/41HaAhbv...
# 4  0528881469  http://ecx.images-amazon.com/images/I/51FnRkJq...
#
#                                          description  \
# 0  The Kelby Training DVD Mastering Blend Modes i...
# 1                                                NaN
# 2                    Digital Organizer and Messenger
# 3  The CLIKR-5 UR5U-8780L remote control is desig...
# 4  Like its award-winning predecessor, the Intell...
#
#                                           categories  \
# 0  [[Electronics, Computers & Accessories, Cables...
# 1  [[Electronics, Computers & Accessories, Cables...
# 2  [[Electronics, Computers & Accessories, PDAs, ...
# 3  [[Electronics, Accessories & Supplies, Audio &...
# 4  [[Electronics, GPS & Navigation, Vehicle GPS, ...
#
#                                                title   price  \
# 0  Kelby Training DVD: Mastering Blend Modes in A...     NaN
# 1  Kelby Training DVD: Adobe Photoshop CS5 Crash ...     NaN
# 2                    Digital Organizer and Messenger    8.15
# 3  CLIKR-5 Time Warner Cable Remote Control UR5U-...   23.36
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  299.99
#
#                  salesRank                                            related  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2  {'Electronics': 144944}  {'also_viewed': ['0545016266', 'B009ECM8QY', '...
# 3                      NaN  {'also_viewed': ['B001KC08A4', 'B00KUL8O0W', '...
# 4                      NaN  {'also_viewed': ['B006ZOI9OY', 'B00C7FKT2A', '...
#
#   brand
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df['related'] = df['related'].astype(str)
df['categories'] = df['categories'].astype(str)
df['salesRank'] = df['salesRank'].astype(str)

# %%
sum(df['related'].isnull())
# Out:
# 0

# %%
df = lowercase_df(df)

# %%
df
# Out:
#               asin                                              imUrl  \
# 0       0132793040  http://ecx.images-amazon.com/images/i/31jiphp%...
# 1       0321732944  http://ecx.images-amazon.com/images/i/31uogm6y...
# 2       0439886341  http://ecx.images-amazon.com/images/i/51k0qa8f...
# 3       0511189877  http://ecx.images-amazon.com/images/i/41haahbv...
# 4       0528881469  http://ecx.images-amazon.com/images/i/51fnrkjq...
# ...            ...                                                ...
# 498191  bt008v9j9u  http://ecx.images-amazon.com/images/i/313e6sjm...
# 498192  bt008sxq4c  http://ecx.images-amazon.com/images/i/31of9onv...
# 498193  bt008g3w52  http://ecx.images-amazon.com/images/i/21wirx5f...
# 498194  bt008uktmw  http://ecx.images-amazon.com/images/i/41tnavmf...
# 498195  bt008t2bgk  http://ecx.images-amazon.com/images/i/41x-15rr...
#
#                                               description  \
# 0       the kelby training dvd mastering blend modes i...
# 1                                                     NaN
# 2                         digital organizer and messenger
# 3       the clikr-5 ur5u-8780l remote control is desig...
# 4       like its award-winning predecessor, the intell...
# ...                                                   ...
# 498191  vehicle suction cup mount (replacement) notice...
# 498192  quatech - 1 port pcmcia to db-25 parallel adap...
# 498193               c2g - 5m ultma usb 2.0 a mini b cble
# 498194                                   keyboard drawer.
# 498195  garmin usb to r232 converter cableusb to rs232...
#
#                                                categories  \
# 0       [['electronics', 'computers & accessories', 'c...
# 1       [['electronics', 'computers & accessories', 'c...
# 2       [['electronics', 'computers & accessories', 'p...
# 3       [['electronics', 'accessories & supplies', 'au...
# 4       [['electronics', 'gps & navigation', 'vehicle ...
# ...                                                   ...
# 498191  [['electronics', 'gps & navigation', 'gps syst...
# 498192  [['electronics', 'computers & accessories', 'c...
# 498193  [['electronics', 'computers & accessories', 'c...
# 498194  [['electronics', 'computers & accessories', 'c...
# 498195  [['electronics', 'computers & accessories', 'c...
#
#                                                     title   price  \
# 0       kelby training dvd: mastering blend modes in a...     NaN
# 1       kelby training dvd: adobe photoshop cs5 crash ...     NaN
# 2                         digital organizer and messenger    8.15
# 3       clikr-5 time warner cable remote control ur5u-...   23.36
# 4       rand mcnally 528881469 7-inch intelliroute tnd...  299.99
# ...                                                   ...     ...
# 498191                                  suction cup mount   21.99
# 498192                     parallel pcmcia card 1port epp   23.99
# 498193         c2g / cables to go 5m ultima usb 2.0 cable   18.91
# 498194                          underdesk keyboard drawer   25.54
# 498195                        usb to r232 converter cable   62.31
#
#                       salesRank  \
# 0                           nan
# 1                           nan
# 2       {'electronics': 144944}
# 3                           nan
# 4                           nan
# ...                         ...
# 498191                      nan
# 498192                      nan
# 498193                      nan
# 498194                      nan
# 498195                      nan
#
#                                                   related     brand
# 0                                                     nan       NaN
# 1                                                     nan       NaN
# 2       {'also_viewed': ['0545016266', 'b009ecm8qy', '...       NaN
# 3       {'also_viewed': ['b001kc08a4', 'b00kul8o0w', '...       NaN
# 4       {'also_viewed': ['b006zoi9oy', 'b00c7fkt2a', '...       NaN
# ...                                                   ...       ...
# 498191              {'buy_after_viewing': ['b000epfcc2']}    garmin
# 498192  {'also_bought': ['b000sr2h4w', 'b001q7x0w6'], ...       NaN
# 498193  {'bought_together': ['b0002d6qjo'], 'buy_after...       c2g
# 498194  {'also_viewed': ['b0002ld0zy', 'b0002lczp0', '...  fellowes
# 498195  {'also_viewed': ['b0007t27h8', 'b00425s1h8', '...    garmin
#
# [498196 rows x 9 columns]
